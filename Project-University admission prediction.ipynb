# %%
import numpy as np
import pandas as pd

# %%
import tensorflow as ts
import keras as keras
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv(r'C:\Users\bhavani\Downloads\Admission_Predict_Ver1.1.csv')

# %%
dataset
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
dataset.isnull().any()
# Out:
# Serial No.           False
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %%
x=dataset.iloc[:,:8].values

# %%
x
# Out:
# array([[  1.  , 337.  , 118.  , ...,   4.5 ,   9.65,   1.  ],
#        [  2.  , 324.  , 107.  , ...,   4.5 ,   8.87,   1.  ],
#        [  3.  , 316.  , 104.  , ...,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [498.  , 330.  , 120.  , ...,   5.  ,   9.56,   1.  ],
#        [499.  , 312.  , 103.  , ...,   5.  ,   8.43,   0.  ],
#        [500.  , 327.  , 113.  , ...,   4.5 ,   9.04,   0.  ]])

# %%
x.shape
# Out:
# (500, 8)

# %%
y = dataset.iloc[:,8:].values

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
y.shape
# Out:
# (500, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_test
# Out:
# array([[ 91.  , 318.  , 106.  ,   2.  ,   4.  ,   4.  ,   7.92,   1.  ],
#        [255.  , 321.  , 114.  ,   4.  ,   4.  ,   5.  ,   9.12,   0.  ],
#        [284.  , 321.  , 111.  ,   3.  ,   2.5 ,   3.  ,   8.9 ,   1.  ],
#        [446.  , 328.  , 116.  ,   5.  ,   4.5 ,   5.  ,   9.08,   1.  ],
#        [462.  , 301.  , 102.  ,   3.  ,   2.5 ,   2.  ,   8.13,   1.  ],
#        [ 16.  , 314.  , 105.  ,   3.  ,   3.5 ,   2.5 ,   8.3 ,   0.  ],
#        [317.  , 298.  , 101.  ,   2.  ,   1.5 ,   2.  ,   7.86,   0.  ],
#        [490.  , 302.  , 110.  ,   3.  ,   4.  ,   4.5 ,   8.5 ,   0.  ],
#        [160.  , 297.  , 100.  ,   1.  ,   1.5 ,   2.  ,   7.9 ,   0.  ],
#        [154.  , 324.  , 105.  ,   3.  ,   3.  ,   4.  ,   8.75,   0.  ],
#        [242.  , 317.  , 103.  ,   2.  ,   2.5 ,   2.  ,   8.15,   0.  ],
#        [251.  , 320.  , 104.  ,   3.  ,   3.  ,   2.5 ,   8.57,   1.  ],
#        [391.  , 314.  , 102.  ,   2.  ,   2.  ,   2.5 ,   8.24,   0.  ],
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(input_dim=8,init="random_uniform",output_dim=30))
model.add(Dense(init="random_uniform",output_dim=30))
model.add(Dense(init="random_uniform",output_dim=1))
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mse'])
model.fit(x_train,y_train,epochs=100,batch_size=32)
# Out:
# C:\Users\bhavani\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=8, units=30, kernel_initializer="random_uniform")`
#   """
# C:\Users\bhavani\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=30, kernel_initializer="random_uniform")`
#
# C:\Users\bhavani\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, kernel_initializer="random_uniform")`
#   import sys
# Epoch 1/100
# 400/400 [==============================] - 3s 7ms/step - loss: 0.2461 - mean_squared_error: 0.2461
# Epoch 2/100
# 400/400 [==============================] - 0s 703us/step - loss: 0.0406 - mean_squared_error: 0.0406
# Epoch 3/100
# 400/400 [==============================] - 0s 469us/step - loss: 0.0220 - mean_squared_error: 0.0220
# Epoch 4/100
# ...

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[0.7255151 ],
#        [0.8204742 ],
#        [0.7480123 ],
#        [0.94497585],
#        [0.69940984],
#        [0.6404088 ],
#        [0.56805825],
#        [0.78885686],
#        [0.51786447],
#        [0.680123  ],
#        [0.58702624],
#        [0.70515084],
#        [0.60121703],
#        [0.73564416],
#        [0.89202565],
#        [0.556127  ],
#        [0.8766483 ],
#        [0.6402012 ],
#        [0.6835636 ],
#        [0.51558805],
#        [0.59400606],
#        [0.7777004 ],
#        [0.57944703],
#        [0.92098117],
#        [0.8601074 ],
#        [0.7135407 ],
#        [0.6867864 ],
#        [0.5194647 ],
#        [0.59674567],
#        [0.6140569 ],
#        [0.66418546],
#        [0.60480666],
#        [0.6829708 ],
#        [0.8754368 ],
#        [0.6087606 ],
#        [0.78587115],
#        [0.8363076 ],
#        [0.89287233],
#        [0.6684501 ],
#        [0.65149105],
#        [0.6692267 ],
#        [0.879955  ],
#        [0.8627447 ],
# ...

# %%
y_test
# Out:
# array([[0.64],
#        [0.85],
#        [0.8 ],
#        [0.91],
#        [0.68],
#        [0.54],
#        [0.54],
#        [0.65],
#        [0.52],
#        [0.79],
#        [0.65],
#        [0.74],
#        [0.64],
#        [0.79],
#        [0.89],
#        [0.43],
#        [0.81],
#        [0.73],
#        [0.8 ],
#        [0.58],
#        [0.57],
#        [0.74],
#        [0.6 ],
#        [0.93],
#        [0.88],
#        [0.67],
#        [0.7 ],
#        [0.57],
#        [0.48],
#        [0.64],
#        [0.69],
#        [0.47],
#        [0.57],
#        [0.87],
#        [0.39],
#        [0.53],
#        [0.84],
#        [0.89],
#        [0.63],
#        [0.7 ],
#        [0.72],
#        [0.86],
#        [0.91],
#        [0.75],
#        [0.74],
#        [0.76],
#        [0.96],
#        [0.81],
#        [0.6 ],
#        [0.62],
#        [0.69],
#        [0.68],
#        [0.59],
#        [0.8 ],
#        [0.71],
#        [0.78],
#        [0.69],
#        [0.89],
# ...

# %%
y_pred[25]
# Out:
# array([0.7135407], dtype=float32)

# %%
y_test[25]
# Out:
# array([0.67])

# %%
y_pred_single=model.predict(np.array([[2,324,107,4,4.0,4.5,8.87,1]]))
y_pred_single
# Out:
# array([[0.7963114]], dtype=float32)

# %%
y_test_single=model.predict(np.array([[2,324,107,4,4.0,4.5,8.87,1]]))
y_test_single
# Out:
# array([[0.7963114]], dtype=float32)

# %%
y_pred_single=model.predict(np.array([[25,336,119,5,4.0,3.5,9.8,1]]))
y_pred_single
# Out:
# array([[0.8670904]], dtype=float32)

# %%
y_test_single=model.predict(np.array([[25,336,119,5,4.0,3.5,9.8,1]]))
y_test_single
# Out:
# array([[0.8670904]], dtype=float32)
